# %% [markdown]
# <a href="https://colab.research.google.com/github/galindovil/Dataframe/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# #Crear una serie
# Arreglo unidimensional de datos

# %%
miSerie=pd.Series([34,56,78,23,34])
print(miSerie)
# Out:
# 0    34
# 1    56
# 2    78
# 3    23
# 4    34
# dtype: int64

# %% [markdown]
# #Diccionarios en python
# Estructura que guarda datos en forma de objetos

# %%
miDiccionario=(
    "nombre":"Casa_1",
    "area":120,
    "Baños": 3,
    "propietarios": [
        "paulo","diana","sonia"
    ],
    "Barrio":(
        "nombre": "Gran Britalia",
        "Localidad": "Bosa"
    )
)

print(miDiccionario)
# Out:
#   File "<ipython-input-18-d208a24548cf>", line 2
#     "nombre":"Casa_1",
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Dataframe
# Estructura de datos en forma Tabla.
#
# la forma simple de crear un dataframe es a partir de un diccionario,
# otra forma puede ser desde hojas de calculo,desde archivos JSON o desde
# archivos CSV (valores separados por coma)

# %%
miDataframe=pd.DataFrame({"si":[10,15],"No":[50,68]})
miDataframe
# Out:
#    si  No
# 0  10  50
# 1  15  68
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['si'].plot(kind='hist', bins=20, title='si')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['No'].plot(kind='hist', bins=20, title='No')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='index', y='si', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# # Nueva sección

# %% [markdown]
# Otro dataframe

# %%
encuesta=pd.DataFrame(
    {
    "Julia":["me gusto","Fue horrible"],
    "Pedro": ["fue delicioso", "no estuvo mal"],
    },
    index=["Restaurante_1","Restaurante_2"]
)
encuesta
# Out:
#                       Julia          Pedro
# Restaurante_1      me gusto  fue delicioso
# Restaurante_2  Fue horrible  no estuvo mal

# %% [markdown]
# #Cargar archivos csv en un dataframe
# Leer el archivo csv

# %%
miCSV=pd.read_csv("Datos.csv")
miCSV.shape
miCSV.head()
# Out:
#    Estudiante_1  Estudiante_2  Estudiante_3
# 0            34            23            45
# 1            45            10            46
# 2            25            30            46

# %%
miNetflix=pd.read_csv("netflix_revenue_updated.csv")
miNetflix.shape
miNetflix.head()
# Out:
#          Date  Global Revenue  UCAN Streaming Revenue  EMEA Streaming Revenue  \
# 0  31-03-2019      4520992000              2256851000              1233379000
# 1  30-06-2019      4923116000              2501199000              1319087000
# 2  30-09-2019      5244905000              2621250000              1428040000
# 3  31-12-2019      5467434000              2671908000              1562561000
# 4  31-03-2020      5767691000              2702776000              1723474000
#
#    LATM Streaming Revenue  APAC Streaming Revenue  UCAN Members  \
# 0               630472000               319602000      66633000
# 1               677136000               349494000      66501000
# 2               741434000               382304000      67114000
# 3               746392000               418121000      67662000
# 4               793453000               483660000      69969000
#
#    EMEA  Members  LATM Members  APAC Members  UCAN ARPU  EMEA ARPU  \
# ...

# %%
miNetflix.describe()
# Out:
#        Global Revenue  UCAN Streaming Revenue  EMEA Streaming Revenue  \
# count    1.700000e+01            1.700000e+01            1.700000e+01
# mean     6.742788e+09            3.068941e+09            2.075164e+09
# std      1.197879e+09            4.209004e+08            4.594011e+08
# min      4.520992e+09            2.256851e+09            1.233379e+09
# 25%      5.767691e+09            2.702776e+09            1.723474e+09
# 50%      7.163282e+09            3.170972e+09            2.343674e+09
# 75%      7.852053e+09            3.350424e+09            2.432239e+09
# max      8.161503e+09            3.608645e+09            2.561831e+09
#
#        LATM Streaming Revenue  APAC Streaming Revenue  UCAN Members  \
# count            1.700000e+01            1.700000e+01  1.700000e+01
# mean             8.629001e+08            6.830686e+08  7.207747e+07
# std              1.349618e+08            2.204141e+08  3.129072e+06
# ...

# %%
miNetflix.rename(columns={"Global Revenue":"Ingresos Globales"})
# Out:
#           Date  Ingresos Globales  UCAN Streaming Revenue  \
# 0   31-03-2019         4520992000              2256851000
# 1   30-06-2019         4923116000              2501199000
# 2   30-09-2019         5244905000              2621250000
# 3   31-12-2019         5467434000              2671908000
# 4   31-03-2020         5767691000              2702776000
# 5   30-06-2020         6148286000              2839670000
# 6   30-09-2020         6435637000              2933445000
# 7   31-12-2020         6644442000              2979505000
# 8   31-03-2021         7163282000              3170972000
# 9   30-06-2021         7341777000              3234643000
# 10  30-09-2021         7483467000              3257697000
# 11  31-12-2021         7709318000              3308788000
# 12  31-03-2022         7867767000              3350424000
# 13  30-06-2022         7970141000              3537863000
# 14  30-09-2022         7925589000              3601565000
# ...

# %%
miNetflix.head()
# Out:
#          Date  Global Revenue  UCAN Streaming Revenue  EMEA Streaming Revenue  \
# 0  31-03-2019      4520992000              2256851000              1233379000
# 1  30-06-2019      4923116000              2501199000              1319087000
# 2  30-09-2019      5244905000              2621250000              1428040000
# 3  31-12-2019      5467434000              2671908000              1562561000
# 4  31-03-2020      5767691000              2702776000              1723474000
#
#    LATM Streaming Revenue  APAC Streaming Revenue  UCAN Members  \
# 0               630472000               319602000      66633000
# 1               677136000               349494000      66501000
# 2               741434000               382304000      67114000
# 3               746392000               418121000      67662000
# 4               793453000               483660000      69969000
#
#    EMEA  Members  LATM Members  APAC Members  UCAN ARPU  EMEA ARPU  \
# ...

# %%
miNetflix.rename(columns={"Global Revenue":"Ingresos Globales"},inplace=True)

# %%
miNetflix.head()
# Out:
#          Date  Ingresos Globales  UCAN Streaming Revenue  \
# 0  31-03-2019         4520992000              2256851000
# 1  30-06-2019         4923116000              2501199000
# 2  30-09-2019         5244905000              2621250000
# 3  31-12-2019         5467434000              2671908000
# 4  31-03-2020         5767691000              2702776000
#
#    EMEA Streaming Revenue  LATM Streaming Revenue  APAC Streaming Revenue  \
# 0              1233379000               630472000               319602000
# 1              1319087000               677136000               349494000
# 2              1428040000               741434000               382304000
# 3              1562561000               746392000               418121000
# 4              1723474000               793453000               483660000
#
#    UCAN Members  EMEA  Members  LATM Members  APAC Members  UCAN ARPU  \
# 0      66633000       42542000      27547000      12141000      11.45
# ...

# %% [markdown]
# #Convertir

# %%
miIngresos=miNetflix["Ingresos Globales"]
miIngresos.count()
# Out:
# 17

# %%
miIngresos.product()
# Out:
# -9223372036854775808

# %% [markdown]
# #Filtrar filas
# seleccionar filas especificas

# %%
miNetflixFiltrado =
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-187c394843dc> in <cell line: 1>()
# ----> 1 miNetflixFiltrado = miIngresos[miIngresos["Ingresos Globales"]]
#       2
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1114
#    1115         # Similar to Index.get_value, but we do not fall back to positional
# -> 1116         loc = self.index.get_loc(label)
#    1117
#    1118         if is_integer(loc):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     347                 raise KeyError(key) from err
# ...

# %%
N
